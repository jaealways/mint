# %%
import sys
sys.path.append("..")

import math
import pandas as pd
import numpy as np


from data_transformation.db_env import DbEnv, db
from data_preprocessing.data_tidying import DataTidying
from data_preprocessing.data_preprocess import DataPreprocess
from data_modeling.time_series_clustering import TimeSeriesClustering

# %%
# 노래 번호 리스트 출력
conn, cursor = DbEnv().connect_sql()
sql = "SELECT DISTINCT num FROM daily_music_cow"
list_music_num = DataTidying().gget_list_from_sql(cursor, sql)

# %%
# 데이터 프레임 생성
# df_price = DataTidying().get_df_price(list_music_num, cursor)
# df_mcpi = DataTidying().get_df_mcpi(cursor)

# %%
# 가장 최근에 저장된 값 불러올 경우 피클 이용
df_price = pd.read_pickle("../storage/df_raw_data/df_price_17-01-01_23-12-31.pkl")
df_mcpi = pd.read_pickle("../storage/df_raw_data/df_mcpi_17-01-01_23-12-31.pkl")

# %%
# 필요할 경우 str_date, end_date 조정
str_date, end_date = '19-01-01', '20-12-31'

# %%
df_price_temp = df_price.loc[:, '20'+str_date: '20'+end_date].dropna(axis=0)
len_cluster = int(len(df_price_temp) ** (2/3))
print('---------- cluster %s 개' % len_cluster)
# Out:
# ---------- cluster 24 개

# %%
# mcpi date가 end_date보다 적어서 임시로 끝에 뺌
df_mcpi_temp = df_mcpi.loc[:, '20'+str_date:]

# df_price_scaled = DataPreprocess().scale_df(df=df_price_temp, method='MinMax')
df_mcpi_scaled = DataPreprocess().scale_df(df=df_mcpi_temp, method='MinMax')

# %%
# exp06, 가법 trend clustering
# df_price_expsmooth06 = DataPreprocess().smooth_time_series(df_time=df_price_temp, level=0.6)

# %%
# 시계열 분해

df_price_resid_add, df_price_trend_add, df_price_season_add = TimeSeriesClustering(str_date, end_date, 'som_add').decompose_time_series(df_price_temp)
# df_price_resid_mul, df_price_trend_mul, df_price_season_mul = TimeSeriesClustering(str_date, end_date, 'som_mul').decompose_time_series(df_price_temp, model='multiplicative')

# %%
# 시계열 분해 결과 scaling

df_price_resid_add_scaled = DataPreprocess().scale_df(df=df_price_resid_add, method='MinMax')
df_price_trend_add_scaled = DataPreprocess().scale_df(df=df_price_trend_add, method='MinMax')
df_price_season_add_scaled = DataPreprocess().scale_df(df=df_price_season_add, method='MinMax')

# df_price_resid_mul_scaled = DataPreprocess().scale_df(df=df_price_resid_mul, method='MinMax')
# df_price_trend_mul_scaled = DataPreprocess().scale_df(df=df_price_trend_mul, method='MinMax')
# df_price_season_mul_scaled = DataPreprocess().scale_df(df=df_price_season_mul, method='MinMax')

# %%
# 클러스터링 맵, 분포도 표시

df_cluster_dst_add_som, df_cluster_add_som = TimeSeriesClustering(str_date, end_date, 'som_add').plot_result_som(df_price_trend_add_scaled, len_cluster, df_trend=df_mcpi_scaled)
# df_cluster_dst_mul_som, df_cluster_mul_som = TimeSeriesClustering(str_date, end_date, 'som_mul').plot_result_som(df_price_trend_mul_scaled, 64, df_trend=df_mcpi_scaled)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<?, ?it/s]

# %%
# 각 클러스터 별 아티스트, 노래 제목 pair 구하기

columns = ['title', 'artist', 'cl_n', 'num']
df_clst_artist_song_add = TimeSeriesClustering(str_date, end_date, 'som_add').make_df_clst_arst_song('daily_music_cow', columns, df_cluster_add_som)
# df_clst_artist_song_mul = TimeSeriesClustering(str_date, end_date, 'som_mul').make_df_clst_arst_song('daily_music_cow', columns, df_cluster_mul_som)

df_clst_artist_song = pd.read_pickle("../storage/df_ts_clst/df_clst_artist_song_%s_%s_%s.pkl" % ('som_add', str_date, end_date))
# Out:
# Cluster 1 번 클러스터 - ['73']
# title: 저녁하늘 --- artist: 에일리
# Cluster 10 번 클러스터 - ['87', '237', '123', '55', '46', '44']
# title: 이름 --- artist: 임재범
# title: 갖고놀래 --- artist: 범키
# title: Beautiful Target --- artist: B1A4
# title: Tic Toc --- artist: 매드클라운
# title: 서울사람들 --- artist: 버스커 버스커
# title: Yesterday --- artist: 박혜경
# Cluster 11 번 클러스터 - ['224', '219', '53', '52', '26', '32', '36', '35']
# title: JUST U --- artist: 정세운
# title: 마카롱 --- artist: 걸스데이
# title: 때려박는 랩 --- artist: 매드클라운
# title: 바질 --- artist: 매드클라운
# title: I'm in love --- artist: 라디
# title: 고마워고마워 --- artist: 라디
# title: Goodbye --- artist: 라디
# title: 너와 함께 있음을 --- artist: 라디
# Cluster 12 번 클러스터 - ['176']
# title: 죽을만큼 아파서 Part.2 --- artist: MC몽
# Cluster 13 번 클러스터 - ['221']
# title: 바람의 유령 --- artist: 제국의아이들
# Cluster 14 번 클러스터 - ['28', '179']
# title: 엄마 --- artist: 라디
# title: 유리 심장 --- artist: 린
# Cluster 15 번 클러스터 - ['50', '49']
# title: Fly --- artist: SUPER JUNIOR-K.R.Y.
# title: 기억할게요 --- artist: 양파
# ...

# %%
# song_num이랑 같은 클러스터였던 곡들 시계열 순으로 추적

list_str_date, list_end_date = ['19-01-01', '19-04-01', '19-07-01', '19-10-01', '20-01-01'], ['20-12-31', '21-03-31', '21-06-31', '21-09-31', '21-12-31']
song_num = '96'
for str_idx, end_idx in zip(list_str_date, list_end_date):
    df_clst_artist_song_temp = pd.read_pickle("../storage/df_ts_clst/df_clst_artist_song_%s_%s_%s.pkl" % ('som_add', str_idx, end_idx))
    clu_song = df_clst_artist_song_temp[df_clst_artist_song_temp['num'] == song_num]['cl_n'].values[0]
    df_clst_artist_song_temp = df_clst_artist_song_temp[df_clst_artist_song_temp['cl_n'] == clu_song]
    print(str_idx, '~', end_idx)
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        print(df_clst_artist_song_temp)
# Out:
# 19-01-01 ~ 20-12-31
#             title artist        cl_n  num
# 0    TTL Listen 2    티아라  Cluster 24  468
# 0         너에게 닿기를   우주소녀  Cluster 24  108
# 0            오늘 밤      린  Cluster 24  169
# 0        Loving U    씨스타  Cluster 24   96
# 0         핑크빛 로맨스    케이윌  Cluster 24  198
# 0             스토커  매드클라운  Cluster 24  207
# 0         Lead Me    씨스타  Cluster 24  225
# 0              안녕    박혜경  Cluster 24   42
# 0            짧은머리     허각  Cluster 24  115
# 0  If You Love Me  NS 윤지  Cluster 24  148
# 19-04-01 ~ 21-03-31
#            title   artist        cl_n  num
# 0        Lead Me      씨스타  Cluster 15  225
# 0           사람냄새       정인  Cluster 15  133
# 0        아무도 모르게       치타  Cluster 15  146
# 0        사랑이 올까요  마이티 마우스  Cluster 15  467
# 0   TTL Listen 2      티아라  Cluster 15  468
# 0  Give It To Me      씨스타  Cluster 15  104
# 0       Loving U      씨스타  Cluster 15   96
# 0        너에게 닿기를     우주소녀  Cluster 15  108
# 0         이상하다 참       민아  Cluster 15   65
# ...
